# %% [markdown]
# # Lab 05: SQLAlchemy Basics

# %% [markdown]
# ### Basis Aufgabe

# %%
from sqlalchemy import create_engine, text

# TODO: Implement

# %%
# Sichere Abfrage (Parameterized Query)
# TODO: Implement

# %% [markdown]
# ### Bonus Herausforderung

# %%
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column, Session

# Model Definition
# TODO: Implement
