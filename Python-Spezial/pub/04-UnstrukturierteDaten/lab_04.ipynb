# %% [markdown]
# # Lab 04: Unstrukturierte Daten

# %% [markdown]
# ### Basis Aufgabe

# %%
from docx import Document
from pypdf import PdfReader

# --- Word Verarbeitung ---
doc = Document('antrag.docx')
applicant_name = None

print("--- Word Analysis ---")
# TODO: Implement

# --- PDF Check ---
print("\n--- PDF Analysis ---")
# TODO: Implement

# %% [markdown]
# ### Bonus Herausforderung

# %%
import pdfplumber
from docx import Document

# Extract Table from PDF
salary_data = []

# TODO: Implement

print(f"Extracted Data: {salary_data}")

# Generate Word Report with Table
report = Document()

# TODO: Implement

print("Report 'report_genehmigung.docx' generated successfully.")
