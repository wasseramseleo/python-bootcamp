# %% [markdown]
# # Lab 06: Pandas & Performance

# %% [markdown]
# ### Basis Aufgabe

# %%
import pandas as pd

# Laden & Inspektion
# TODO: Implement

print("--- Info ---")
# TODO: Implement

print("\n--- Head ---")
# TODO: Implement

# %%
# Selektion (Boolean Indexing)
# TODO: Implement

# Reporting
# TODO: Implement

# %% [markdown]
# ### Bonus Herausforderung

# %%
import time

# Der "Naive" Ansatz (Loop)
print("\nStarting Loop Calculation...")
start_loop = time.time()

# TODO: Implement

end_loop = time.time()
loop_duration = end_loop - start_loop
print(f"Loop Duration: {loop_duration:.4f} seconds")

# 3. Der "Pandas" Ansatz (Vektorisierung)
print("Starting Vectorized Calculation...")
start_vec = time.time()

# TODO: Implement

end_vec = time.time()
vec_duration = end_vec - start_vec
print(f"Vector Duration: {vec_duration:.4f} seconds")

# Vergleich
factor = loop_duration / vec_duration
print(f"\nVectorization was {factor:.1f}x faster!")
