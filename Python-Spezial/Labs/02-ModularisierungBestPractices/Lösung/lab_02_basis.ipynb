# %% [markdown]
# # Lab 02: Modularisierung & Resilience

# %% [markdown]
# ### Basis Aufgabe

# %%
from datetime import datetime

# 1. Funktion für Währungsumwandlung
def convert_currency(amount, currency, rate=0.90):
  """Konvertiert Fremdwährung in EUR."""
  if currency == "USD":
    return amount * rate
  # Annahme: Andere Währungen sind bereits EUR oder werden ignoriert
  return amount


# 2. Funktion für Verarbeitung
def process_ledger(transaction_list):
  """Iteriert über Transaktionen und berechnet den Endstand."""
  balance = 0.0

  for tx in transaction_list:
    # Extraktion
    amount = tx["amount"]
    curr = tx["currency"]
    t_type = tx["type"]

    # Nutzung der Helper-Funktion
    amount_in_eur = convert_currency(amount, curr)

    # Logik
    if t_type == "deposit":
      balance += amount_in_eur
    elif t_type in ["withdrawal", "payment"]:
      balance -= amount_in_eur

  return balance


# Ausführung
transactions = [
    {"id": 101, "type": "deposit", "amount": 1500.00, "currency": "EUR"},
    {"id": 102, "type": "withdrawal", "amount": 50.00, "currency": "EUR"},
    {"id": 103, "type": "deposit", "amount": 200.00, "currency": "USD"},
    {"id": 104, "type": "payment", "amount": 25.50, "currency": "EUR"},
    {"id": 105, "type": "withdrawal", "amount": 1000.00, "currency": "USD"},
]

final_balance = process_ledger(transactions)

# 3. Datetime Output
now = datetime.now()
print(f"Final Balance: {final_balance:.2f} EUR")
print(f"Report generated at: {now}")
# Out:
# Final Balance: 704.50 EUR
# Report generated at: 2025-12-14 16:42:16.108619
